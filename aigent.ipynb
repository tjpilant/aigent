# %%
# %run aigent_gui.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/aiengineers/aigent/aigent_gui.py:3
#       1 import sys
#       2 import os
# ----> 3 from PyQt5.QtWidgets import QApplication, QMainWindow, QWidget, QVBoxLayout, QHBoxLayout, QPushButton, QLineEdit, QLabel, QFileDialog, QMessageBox, QSpinBox, QComboBox
#       4 from pdf_converter import ProjectInfo, AgentTraits, start_conversion, split_large_pdf, load_config, save_config
#       6 class AIGentGUI(QMainWindow):
#
# ModuleNotFoundError: No module named 'PyQt5'
